# %%
import matplotlib.pyplot as plt

# %%
plt.plot((0,25,50,65,80,90),(0,1041,2082,2708,3333,3750), color = 'red')
plt.plot((0,18,40,60,75,85),(0,750,1666,2500,3125,3541))

# %%
plt.plot((0,10,20,30,40,50,60,70),(0,166,333,416,583,750,833,1000))

# %%
plt.plot((0,2,4,6,8),(0,20,30,50,65))

# %%
plt.plot((4,15,28,40,48),(35,30,25,21,18))

# %%
plt.plot((4,10,14,22,25),(35,30,25,20,10))

# %%
plt.plot((4,8,14,22,24),(35,30,25,15,10))
